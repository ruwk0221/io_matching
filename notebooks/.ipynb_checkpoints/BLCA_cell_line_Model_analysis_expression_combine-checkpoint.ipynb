# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('__file__'))))
import jReversion as jR
from LDOI import BooleanDOI_processing as BDOIp
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, balanced_accuracy_score
import networkx as nx
from statannot import add_stat_annotation
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test
kmf = KaplanMeierFitter()

# %%
sys.path
# Out:
# ['/home/jijoo/theor/lib/python35.zip',
#  '/home/jijoo/theor/lib/python3.5',
#  '/home/jijoo/theor/lib/python3.5/plat-x86_64-linux-gnu',
#  '/home/jijoo/theor/lib/python3.5/lib-dynload',
#  '/usr/lib/python3.5',
#  '/usr/lib/python3.5/plat-x86_64-linux-gnu',
#  '',
#  '/home/jijoo/theor/lib/python3.5/site-packages',
#  '/home/jijoo/theor/lib/python3.5/site-packages/IPython/extensions',
#  '/home/jijoo/.ipython',
#  '/home/jijoo/tmp/pycharm_project_225']

# %%
oncoprint_pd = pd.read_csv('../data/BLCA_200919/CCLE_DATA_oncoprint.tsv', sep='\t')
print(oncoprint_pd.head())
# Out:
#   track_name track_type PLCPRF5_LIVER   NCIH510_LUNG  NCIH2227_LUNG  \
# 0       ATF2        CNA           NaN  Amplification  Amplification
# 1        ATM        CNA           NaN            NaN            NaN
# 2       ELK1        CNA           NaN            NaN            NaN
# 3        FOS        CNA           NaN            NaN            NaN
# 4       FRS2        CNA           NaN            NaN            NaN
#
#    TT_OESOPHAGUS TE4_OESOPHAGUS   SLR26_KIDNEY      PC14_LUNG   COV362_OVARY  \
# 0  Amplification  Amplification  Amplification  Amplification  Amplification
# 1  Amplification  Deep Deletion  Deep Deletion            NaN            NaN
# 2  Deep Deletion  Amplification            NaN  Deep Deletion            NaN
# 3            NaN            NaN            NaN  Amplification            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    ... A204_SOFT_TISSUE BDCM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE HEKTE_KIDNEY  \
# 0  ...              NaN                                     NaN          NaN
# 1  ...              NaN                                     NaN          NaN
# 2  ...              NaN                                     NaN          NaN
# 3  ...              NaN                                     NaN          NaN
# 4  ...              NaN                                     NaN          NaN
#
#   HS274T_BREAST HS604T_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 0           NaN                                       NaN
# 1           NaN                                       NaN
# 2           NaN                                       NaN
# 3           NaN                                       NaN
# 4           NaN                                       NaN
#
#   HS611T_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE KYM1_SOFT_TISSUE  \
# 0                                       NaN              NaN
# 1                                       NaN              NaN
# 2                                       NaN              NaN
# 3                                       NaN              NaN
# 4                                       NaN              NaN
#
#   MHHNB11_AUTONOMIC_GANGLIA MV411_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 0                       NaN                                      NaN
# 1                       NaN                                      NaN
# 2                       NaN                                      NaN
# 3                       NaN                                      NaN
# 4                       NaN                                      NaN
#
#   OELE_OVARY
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 963 columns]

# %%
oncoprint_pd = pd.melt(oncoprint_pd, id_vars=['track_name', 'track_type'], var_name='Case ID', value_name='event')
print(oncoprint_pd.head())
# Out:
#   track_name track_type        Case ID event
# 0       ATF2        CNA  PLCPRF5_LIVER   NaN
# 1        ATM        CNA  PLCPRF5_LIVER   NaN
# 2       ELK1        CNA  PLCPRF5_LIVER   NaN
# 3        FOS        CNA  PLCPRF5_LIVER   NaN
# 4       FRS2        CNA  PLCPRF5_LIVER   NaN

# %%
oncoprint_blca_pd = oncoprint_pd[oncoprint_pd['Case ID'].str.contains('URINAR')]
oncoprint_blca_pd['cell line'] = oncoprint_blca_pd['Case ID'].str.replace('_URINARY_TRACT', '')
print(oncoprint_blca_pd.head())
# Out:
#       track_name track_type               Case ID event cell line
# 12920       ATF2        CNA  VMCUB1_URINARY_TRACT   NaN    VMCUB1
# 12921        ATM        CNA  VMCUB1_URINARY_TRACT   NaN    VMCUB1
# 12922       ELK1        CNA  VMCUB1_URINARY_TRACT   NaN    VMCUB1
# 12923        FOS        CNA  VMCUB1_URINARY_TRACT   NaN    VMCUB1
# 12924       FRS2        CNA  VMCUB1_URINARY_TRACT   NaN    VMCUB1
# /home/jijoo/theor/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
gene_node_pd = pd.read_csv('../data/BLCA_200919/Grieco_gene_node_oncoKB_mapping.csv')
# print(gene_node_pd.head())
# table_original_network = pd.read_csv('../data/Grieco_table_for_original_network.tsv', sep='\t').sort_values(by='node')

# %%
# original
Model = jR.grieco()
BooleanRuleFileName = '../'+Model['BooleanRule_filename']
NetworkName = Model['network_name']

NumInputs = Model['num_inputs']
NumInputConditions = Model['num_input_conditions']

InputConditions = Model['input_conditions']

OutputNodes = Model['output_nodes']
InputNodes = Model['input_nodes']

# Set parameters
# Note the node name for Gread is the index (integer), one can encode the nodename by adding prefix and suffix
# If the node name from the input file is not this simple, one need to create a dictionary to record the mapping
Prefix, Suffix = 'n', 'n'

TempI = jR.initialize(BooleanRuleFileName, Prefix, Suffix)
Mapping = TempI['mapping']
InverseMapping = TempI['inverse_mapping']
GRead = TempI['Gread']
ReadNodes = TempI['read_nodes']
if Model['reduction_required']:
    GRead = BDOIp.Get_reduced_network(GRead)

# form expanded network
# GExpanded = BDOIp.Get_expanded_network(GRead, prefix=Prefix, suffix=Suffix)
# nx.write_gml(GExpanded, NetworkName + '_expanded_network.gml')
try:
    GExpanded = nx.read_gml('../networks/' + NetworkName + '_expanded_network.gml')
except IOError:
    GExpanded = BDOIp.Get_expanded_network(GRead, prefix=Prefix, suffix=Suffix)
    nx.write_gml(GExpanded, '../networks/' + NetworkName + '_expanded_network.gml')

TempGIOW = jR.get_input_output_relation(GExpanded, Mapping, InverseMapping, InputConditions, OutputNodes,
                                        constant_nodes=[])
LDOIs = TempGIOW['LDOIs']
GeneLDOIs = TempGIOW['gene_LDOIs']
Conflicts = TempGIOW['conflicts']
GeneConflicts = TempGIOW['gene_conflicts']
IORelation = TempGIOW['io_relation']
GRemained = TempGIOW['G_remained']

# %%
# IORelation
# print(IORelation.shape)

# %%
# oncoprint_blca_pd[oncoprint_blca_pd['track_type']=='FUSION'].dropna()

# %%
# oncoprint_blca_pd[oncoprint_blca_pd['track_type']=='MUTATIONS'].dropna()

# %%
# print(set(oncoprint_blca_pd['event']))
# print(gene_node_pd.head())

# %%
oncoprint_blca_node_pd = pd.merge(oncoprint_blca_pd.dropna(), gene_node_pd, left_on='track_name', right_on='gene_symbol', how='left')
# print(oncoprint_blca_node_pd.head())

# %%
# node_oncoKB_pd = pd.read_csv('../data/BLCA_200919/node_oncoKB.csv')
# oncoprint_blca_node_oncoKB_pd = pd.merge(oncoprint_blca_node_pd, node_oncoKB_pd, left_on='node_name', right_on='node', how='left')
# print(oncoprint_blca_node_oncoKB_pd.head())

# %%
# oncoprint_blca_node_pd[np.logical_and(oncoprint_blca_node_pd['track_type'] == 'MUTATIONS', oncoprint_blca_node_pd['event'].str.contains('passenger') == False)]

# %%
# IO compare
def io_compare(wt_io, mut_io):
    """
    wt_io: numpy.ndarray(1, 2**n)
    mut_io: numpy.ndarray(1, 2**n)
    """
    _, num_input_conditions = wt_io.shape
    compare = (wt_io == mut_io)
    ratio = np.sum(compare) / float(num_input_conditions)
    
    return {'compare': compare,
             'ratio': ratio}

# %%
# result = io_compare(IORelation, IORelation)
# print(result['ratio'])

# %%
# cell line
# blca_cell_line_node_alteration_pd = pd.pivot_table(oncoprint_blca_node_pd.loc[oncoprint_blca_node_pd['track_type']=='CNA'], index='cell line', columns='node_name', values='event', aggfunc=lambda x: ' '.join(x))
# pd.pivot_table(oncoprint_melt_pd.fillna(''), index=['Case ID', 'track_name'], columns='track_type', values='event', aggfunc=lambda x: ' '.join(x))
# print(blca_cell_line_node_alteration_pd.head())

# %%
# cell_line = 'HT1376'
# cna_blaca_node_pd = oncoprint_blca_node_pd.loc[oncoprint_blca_node_pd['track_type']=='CNA']
# cell_line_pd = cna_blaca_node_pd.loc[cna_blaca_node_pd['cell line'] == cell_line, ['track_name', 'event', 'node_name']]

# alteration_set = set()
# cell_line_pd['alteration'] = 100 * (cell_line_pd['event'] == 'Amplification') - 100 * (cell_line_pd['event'] == 'Deep Deletion')
# cell_line_pd['count'] = 1
# cell_line_pivot_pd = pd.pivot_table(cell_line_pd, index='node_name', values=['alteration', 'count'], aggfunc=np.sum)
# print(cell_line_pivot_pd.head())

# %%
# cell_line_pivot_reset_pd = cell_line_pivot_pd.reset_index()
# gof = list(cell_line_pivot_reset_pd.loc[cell_line_pivot_reset_pd['alteration'] > 0, 'node_name'])
# lof = ['~'+x for x in cell_line_pivot_reset_pd.loc[cell_line_pivot_reset_pd['alteration'] < 0, 'node_name']]
# # alteration_set = set(gof).union(set(lof))
# print(alteration_set)

# MutTempGIOW = jR.get_input_output_relation(GExpanded, Mapping, InverseMapping, InputConditions, OutputNodes,
#                                         constant_nodes=gof+lof)
# mut_io = MutTempGIOW['io_relation']

# print(io_compare(IORelation, mut_io))

# %%
# print(mut_io)
# print(IORelation)

# %%
oncoprint_blca_node_pd['mutation_sign'] = 1*(oncoprint_blca_node_pd['oncoKB'] == 'Oncogene') - 1*(oncoprint_blca_node_pd['oncoKB'] == 'Tumor Suppressor')
cna_blca_mutation_pd = oncoprint_blca_node_pd.loc[np.logical_or(oncoprint_blca_node_pd['track_type']=='CNA', oncoprint_blca_node_pd['track_type']=='MUTATIONS')]
# cna_blaca_node_pd = oncoprint_blca_node_pd.loc[oncoprint_blca_node_pd['track_type']=='CNA']
blca_cell_line_set = set(cna_blca_mutation_pd['cell line'])

# %%
result = pd.DataFrame(columns=['cell line', 'mut_io_ratio', 'rc_io_ratio', 'rc_io'])

for cell_line in blca_cell_line_set:
    cell_line_pd = cna_blca_mutation_pd.loc[cna_blca_mutation_pd['cell line'] == cell_line, ['track_name', 'event', 'node_name', 'mutation_sign', 'oncoKB']]

#     alteration_set = set()
    cell_line_pd['alteration'] = 100 * (cell_line_pd['event'] == 'Amplification') - 100 * (cell_line_pd['event'] == 'Deep Deletion') - 10 * (cell_line_pd['event'].str.contains('Truncating mutation')) + 1 * (cell_line_pd['event'].str.contains('Missense Mutation')) * cell_line_pd['mutation_sign']
    cell_line_pd['count'] = 1
    cell_line_pivot_pd = pd.pivot_table(cell_line_pd, index='node_name', values=['alteration', 'count'], aggfunc=np.sum)
#     print(cell_line_pivot_pd.head(15))
    cell_line_pivot_reset_pd = cell_line_pivot_pd.reset_index()
    gof = list(cell_line_pivot_reset_pd.loc[cell_line_pivot_reset_pd['alteration'] > 0, 'node_name'])
    lof = ['~'+x for x in cell_line_pivot_reset_pd.loc[cell_line_pivot_reset_pd['alteration'] < 0, 'node_name']]
    # alteration_set = set(gof).union(set(lof))
#     print(alteration_set)

    MutTempGIOW = jR.get_input_output_relation(GExpanded, Mapping, InverseMapping, InputConditions, OutputNodes,
                                            constant_nodes=gof+lof)
    mut_io = MutTempGIOW['io_relation']
    mut_io_compare = io_compare(IORelation, mut_io)
    gof_rc = [x for x in gof if x is not 'AKT']
    lof_rc = lof + ['~AKT']
    RCTempGIOW = jR.get_input_output_relation(GExpanded, Mapping, InverseMapping, InputConditions, OutputNodes,
                                            constant_nodes=gof_rc + lof_rc)
    rc_io = RCTempGIOW['io_relation']
    rc_io_compare = io_compare(IORelation, rc_io)
    
    result = result.append(pd.Series({'cell line': cell_line, 'mut_io_ratio': mut_io_compare['ratio'], 'rc_io_ratio': rc_io_compare['ratio'], 'rc_io':str(rc_io)}), ignore_index=True)

# %%
# Out:
#    cell line  mut_io_ratio  rc_io_ratio  \
# 0      UMUC1          0.00         0.00
# 1      KMBC2          0.00         0.00
# 2      JMSU1          0.00         0.00
# 3    RT11284          0.00         0.00
# 4     SCABER          0.00         0.00
# 5    BFTC905          0.00         0.00
# 6     TCCSUP          0.00         0.00
# 7      UMUC3          0.00         0.00
# 8        T24          0.00         0.00
# 9      CAL29          0.00         0.00
# 10    KU1919          0.00         0.50
# 11    HT1376          0.00         0.00
# 12       RT4          0.50         0.50
# 13       J82          0.00         0.00
# 14      BC3C          0.00         0.00
# 15     RT112          0.00         0.00
# 16    SW1710          0.00         0.00
# 17    VMCUB1          0.00         0.00
# 18    HT1197          0.75         0.75
# 19     SW780          0.00         0.00
#
#                                                 rc_io
# 0   [[list(['~Apoptosis', '~Growth_Arrest'])\n  li...
# 1   [[list(['~Apoptosis', '~Growth_Arrest'])\n  li...
# 2   [[list(['~Apoptosis', '~Growth_Arrest', '~Prol...
# 3   [[list(['~Apoptosis', '~Growth_Arrest', '~Prol...
# 4   [[list(['~Apoptosis', '~Growth_Arrest'])\n  li...
# 5   [[list(['Proliferation', '~Apoptosis', '~Growt...
# 6   [[list(['~Apoptosis', '~Growth_Arrest'])\n  li...
# 7   [[list(['~Apoptosis', '~Growth_Arrest', '~Prol...
# 8   [[list(['~Apoptosis', '~Growth_Arrest'])\n  li...
# 9   [[list(['~Apoptosis', '~Growth_Arrest'])\n  li...
# 10  [[list([]) list([]) list([]) list([]) list([])...
# 11  [[list(['~Apoptosis', '~Growth_Arrest', '~Prol...
# 12  [[list(['~Apoptosis', '~Growth_Arrest', '~Prol...
# 13  [[list(['~Apoptosis', '~Growth_Arrest', '~Prol...
# 14  [[list(['~Apoptosis', '~Growth_Arrest'])\n  li...
# 15  [[list(['~Apoptosis', '~Growth_Arrest'])\n  li...
# 16  [[list(['~Apoptosis', '~Growth_Arrest', '~Prol...
# 17  [[list(['~Apoptosis', '~Growth_Arrest', '~Prol...
# 18  [[list([]) list(['Apoptosis', 'Growth_Arrest',...
# 19  [[list(['~Apoptosis', '~Growth_Arrest', '~Prol...

# %%
# result.to_csv('partial_rc_result.csv')

# %%
# blca_cell_line_set = set(cna_blca_mutation_pd['cell line'])
drugs = ['~AKT', '~BCL2', '~FGFR3', '~MAP3K1_3', '~PLCG', '~PPP2CA', '~RAS', '~SOS']

# %%
result2 = pd.DataFrame(columns=(['cell line', 'mut_io_ratio'] + drugs))
for cell_line in blca_cell_line_set:
    temp_dict = dict()
    cell_line_pd = cna_blca_mutation_pd.loc[cna_blca_mutation_pd['cell line'] == cell_line, ['track_name', 'event', 'node_name', 'mutation_sign', 'oncoKB']]

#     alteration_set = set()
    cell_line_pd['alteration'] = 100 * (cell_line_pd['event'] == 'Amplification') - 100 * (cell_line_pd['event'] == 'Deep Deletion') - 10 * (cell_line_pd['event'].str.contains('Truncating mutation')) + 1 * (cell_line_pd['event'].str.contains('Missense Mutation')) * cell_line_pd['mutation_sign']
    cell_line_pd['count'] = 1
    cell_line_pivot_pd = pd.pivot_table(cell_line_pd, index='node_name', values=['alteration', 'count'], aggfunc=np.sum)
#     print(cell_line_pivot_pd.head(15))
    cell_line_pivot_reset_pd = cell_line_pivot_pd.reset_index()
    gof = list(cell_line_pivot_reset_pd.loc[cell_line_pivot_reset_pd['alteration'] > 0, 'node_name'])
    lof = ['~'+x for x in cell_line_pivot_reset_pd.loc[cell_line_pivot_reset_pd['alteration'] < 0, 'node_name']]
    # alteration_set = set(gof).union(set(lof))
#     print(alteration_set)

    MutTempGIOW = jR.get_input_output_relation(GExpanded, Mapping, InverseMapping, InputConditions, OutputNodes,
                                            constant_nodes=gof+lof)
    mut_io = MutTempGIOW['io_relation']
    mut_io_compare = io_compare(IORelation, mut_io)
    temp_dict['cell line'] = cell_line
    temp_dict['mut_io_ratio'] = mut_io_compare['ratio']
    for drug in drugs:
        
        gof_rc = [x for x in gof if x is not drug[1:]]
        lof_rc = lof + [drug]
        RCTempGIOW = jR.get_input_output_relation(GExpanded, Mapping, InverseMapping, InputConditions, OutputNodes,
                                                constant_nodes=gof_rc + lof_rc)
        rc_io = RCTempGIOW['io_relation']
        rc_io_compare = io_compare(IORelation, rc_io)
        temp_dict[drug] = rc_io_compare['ratio']

    result2 = result2.append(pd.Series(temp_dict), ignore_index=True)

# %%
test = cna_blca_mutation_pd.loc[:, ['cell line', 'track_name', 'event', 'node_name', 'mutation_sign', 'oncoKB']]

#     alteration_set = set()
test['alteration'] = 100 * (test['event'] == 'Amplification') - 100 * (test['event'] == 'Deep Deletion') - 10 * (test['event'].str.contains('Truncating mutation')) + 1 * (test['event'].str.contains('Missense Mutation')) * test['mutation_sign']
test['count'] = 1
test_pivot_pd = pd.pivot_table(test, index=['cell line', 'node_name'], values=['alteration', 'count'], aggfunc=np.sum)

# %%
f, axes = plt.subplots(2, 1, figsize=(15, 10))
sns.countplot(data=test, x='alteration', ax=axes[0])
sns.countplot(data=test_pivot_pd, x='alteration', ax=axes[1])

# %%
test.loc[test['event'].str.contains('Truncating mutation'), :]
# Out:
#     cell line track_name                                     event node_name  \
# 7      VMCUB1     MAP3K2  Truncating mutation (putative passenger)  MAP3K1_3
# 20      KMBC2     CDKN1A     Truncating mutation (putative driver)       p21
# 39      UMUC3        ATM     Truncating mutation (putative driver)       ATM
# 42      UMUC3     MAP3K2  Truncating mutation (putative passenger)  MAP3K1_3
# 47      JMSU1        ATM     Truncating mutation (putative driver)       ATM
# 50      JMSU1       SOS1  Truncating mutation (putative passenger)       SOS
# 60     SCABER     CDKN2A     Truncating mutation (putative driver)       p14
# 70    BFTC905       TP53     Truncating mutation (putative driver)       p53
# 81    RT11284       TP53     Truncating mutation (putative driver)       p53
# 91     HT1376     CDKN1A     Truncating mutation (putative driver)       p21
# 104       RT4       SOS2  Truncating mutation (putative passenger)       SOS
# 135     RT112     CDKN1A     Truncating mutation (putative driver)       p21
# 136     RT112       TP53     Truncating mutation (putative driver)       p53
# 142      BC3C       AKT1  Truncating mutation (putative passenger)       AKT
# 159    TCCSUP       TP53     Truncating mutation (putative driver)       p53
# 161       T24       TP53     Truncating mutation (putative driver)       p53
#
#      mutation_sign            oncoKB  alteration  count
# 7                0               NaN         -10      1
# 20              -1  Tumor Suppressor         -10      1
# 39              -1  Tumor Suppressor         -10      1
# 42               0               NaN         -10      1
# 47              -1  Tumor Suppressor         -10      1
# 50               1          Oncogene         -10      1
# 60              -1  Tumor Suppressor         -10      1
# 70              -1  Tumor Suppressor         -10      1
# 81              -1  Tumor Suppressor         -10      1
# 91              -1  Tumor Suppressor         -10      1
# 104              0               NaN         -10      1
# 135             -1  Tumor Suppressor         -10      1
# 136             -1  Tumor Suppressor         -10      1
# 142              1          Oncogene         -10      1
# 159             -1  Tumor Suppressor         -10      1
# 161             -1  Tumor Suppressor         -10      1

# %%
set(oncoprint_blca_node_pd['track_type'])
# Out:
# {'CNA', 'FUSION', 'MUTATIONS'}
